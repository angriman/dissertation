# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
x = np.arange(1, 1000)
y = np.log(x)
slope, intercept, r, p, se = linregress(x, y)
plt.semilogx(x, y)
plt.semilogx(x, x * slope + intercept)
